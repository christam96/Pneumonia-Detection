# %% [markdown]
# # Chest X-Ray Images: Detecting Pneumonia

# %% [markdown]
# ## Table of Contents
#     1. Introduction & Setup
#     2. Loading the data
#     3. Data visualization
#     4. Data pre-processing
#     5. Building a model

# %% [markdown]
# ## 1. Introduction & Setup
# * This notebook explores methods of using a CNN to classify X-ray images of pneumonia using the 'Chest X-Ray Images (Pneumonia)' dataset from Kaggle (link: https://www.kaggle.com/amyjang/tensorflow-pneumonia-classification-on-x-rays).

# %%
# Imports
import cv2
import os
import tempfile
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

print(tf.__version__)
# Out:
# 2.4.0-dev20200818

# %%
# Constants
IMG_SIZE = (200,200)
BATCH_SIZE = 64
NUM_EPOCHS = 10

# %% [markdown]
# ## 2. Loading the data

# %%
path = 'chest_xray/chest_xray/'
dirs = {}
for i in ['train', 'val', 'test']:
    dirs[i] = tf.keras.preprocessing.image_dataset_from_directory(
        path+i, 
        seed=123,
        image_size=IMG_SIZE,
        batch_size=BATCH_SIZE)
# Out:
# Found 5216 files belonging to 2 classes.
# Found 16 files belonging to 2 classes.
# Found 624 files belonging to 2 classes.

# %% [markdown]
# ## 3. Data visualization

# %% [markdown]
# ###### Write function to check label.

# %%
# 0 - Normal
# 1 - Pneumonia
def check_label(filename):
    # Split filename on delimeter '/'
    label = tf.strings.split(filename, '/')
    # Label directory is stored second from last
    if label[-2] == 'NORMAL': return 0 
    else: return 1

# %% [markdown]
# ###### Retrieve files in respective directories.

# %%
training_set = tf.io.gfile.glob(str('chest_xray/train/*/*'))
validation_set = tf.io.gfile.glob(str('chest_xray/val/*/*'))

# %% [markdown]
# ###### Plot first 25 images in training set.

# %%
plt.figure(figsize=(20,20))
for i in range(25):
    ax = plt.subplot(5,5,i+1)
    plt.imshow(Image.open(training_set[i]))
    if check_label(training_set[i]): 
        plt.title("PNEUMONIA")
    else:
        plt.title("NORMAL")
        plt.axis("off")

# %% [markdown]
# ###### Plot first 16 images in the validation set.

# %%
plt.figure(figsize=(20,20))
for i in range(16):
    ax = plt.subplot(5,5,i+1)
    plt.imshow(Image.open(validation_set[i]))
    if check_label(validation_set[i]): 
        plt.title("PNEUMONIA")
    else:
        plt.title("NORMAL")
        plt.axis("off")

# %% [markdown]
# ###### Check ratio of labels (how balanced is the data?).

# %%
# Counters for each label
normal = 0
pneumonia = 0

# Iterate through files in training set and check labels
for file in training_set:
    if check_label(file) == 0:
        normal += 1
    else:
        pneumonia += 1

counts = [normal, pneumonia]
plt.bar(['Normal', 'Pneumonia'], counts)
plt.title('Ratio of Labeled Images')
plt.show()

print('Normal: ', normal)
print('Pneumonia: ', pneumonia)
# Out:
# Normal:  1341
# Pneumonia:  3875

# %% [markdown]
# ## 4. Data Preprocessing

# %% [markdown]
# ###### Correct for data imbalancing.

# %%
initial_bias = np.log([pneumonia/normal])
print(initial_bias)
# Out:
# [1.06113006]

# %% [markdown]
# ###### Instantiate keras normalization layer.

# %%
normalization_layer = tf.keras.layers.experimental.preprocessing.Rescaling(1./255)

# %% [markdown]
# ###### Configure dataset for performance.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

train_tensors = dirs['train'].cache().prefetch(buffer_size=AUTOTUNE)
val_tensors = dirs['val'].cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ## 5. Build a model

# %% [markdown]
# ###### Define the metrics to be used to evaluate the model later.

# %%
METRICS = [
      keras.metrics.TruePositives(name='tp'),
      keras.metrics.FalsePositives(name='fp'),
      keras.metrics.TrueNegatives(name='tn'),
      keras.metrics.FalseNegatives(name='fn'), 
      keras.metrics.BinaryAccuracy(name='accuracy'),
      keras.metrics.Precision(name='precision'),
      keras.metrics.Recall(name='recall'),
      keras.metrics.AUC(name='auc'),
]

# %% [markdown]
# ### V1 - Set output bias

# %%
# Function to make model
def make_model(metrics = METRICS, output_bias=None):
    if output_bias is not None:
        output_bias = tf.keras.initializers.Constant(output_bias)
    model = tf.keras.Sequential([
      layers.experimental.preprocessing.Rescaling(1./255),
      layers.Conv2D(32, 3, activation='relu'),
      layers.MaxPooling2D(),
      layers.Conv2D(32, 3, activation='relu'),
      layers.MaxPooling2D(),
      layers.Flatten(),
      layers.Dense(128, activation='relu'),
      layers.Dense(1, activation='sigmoid',
                         bias_initializer=output_bias),
    ])

    model.compile(optimizer=keras.optimizers.Adam(lr=1e-3),
                  loss=keras.losses.BinaryCrossentropy(from_logits=False),
                  metrics=metrics)

    return model

# Make and fit model
model = make_model(output_bias = initial_bias)
history = model.fit(
  dirs['train'],
  validation_data=dirs['val'],
  epochs=NUM_EPOCHS
)

# Plot accuracy and loss
fig, ax = plt.subplots(1, 2, figsize=(10, 3))
ax = ax.ravel()

for i, met in enumerate(['accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])  
    
# Test
test_data = []
test_labels = []
input_path = 'chest_xray/chest_xray/'
for cond in ['/NORMAL/', '/PNEUMONIA/']:
    for img in (os.listdir(input_path + 'test' + cond)):
        img = plt.imread(input_path+'test'+cond+img)
        img = cv2.resize(img, (200, 200))
        img = np.dstack([img, img, img])
        img = img.astype('float32') / 255
        if cond=='/NORMAL/':
            label = 0
        elif cond=='/PNEUMONIA/':
            label = 1
        test_data.append(img)
        test_labels.append(label)

test_data = np.array(test_data)
test_labels = np.array(test_labels)

preds = model.predict(dirs['test'])

acc = accuracy_score(test_labels, np.round(preds))*100
cm = confusion_matrix(test_labels, np.round(preds))
tn, fp, fn, tp = cm.ravel()

print('CONFUSION MATRIX ------------------')
print(cm)

print('\nTEST METRICS ----------------------')
precision = tp/(tp+fp)*100
recall = tp/(tp+fn)*100
print('Accuracy: {}%'.format(acc))
print('Precision: {}%'.format(precision))
print('Recall: {}%'.format(recall))
print('F1-score: {}'.format(2*precision*recall/(precision+recall)))

print('\nTRAIN METRIC ----------------------')
print('Train acc: {}'.format(np.round((history.history['accuracy'][-1])*100, 2)))
# Out:
# Epoch 1/10
# 82/82 [==============================] - 31s 373ms/step - loss: 1.0252 - tp: 1898.4337 - fp: 372.8313 - tn: 323.7349 - fn: 91.4578 - accuracy: 0.7943 - precision: 0.8135 - recall: 0.9432 - auc: 0.7398 - val_loss: 0.4589 - val_tp: 8.0000 - val_fp: 4.0000 - val_tn: 4.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.7500 - val_precision: 0.6667 - val_recall: 1.0000 - val_auc: 0.9531
# Epoch 2/10
# 82/82 [==============================] - 21s 256ms/step - loss: 0.1007 - tp: 1960.2048 - fp: 52.4217 - tn: 630.5904 - fn: 43.2410 - accuracy: 0.9620 - precision: 0.9724 - recall: 0.9774 - auc: 0.9918 - val_loss: 0.2916 - val_tp: 8.0000 - val_fp: 3.0000 - val_tn: 5.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.8125 - val_precision: 0.7273 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 3/10
# 82/82 [==============================] - 21s 255ms/step - loss: 0.0859 - tp: 1954.0120 - fp: 45.1687 - tn: 650.1928 - fn: 37.0843 - accuracy: 0.9695 - precision: 0.9781 - recall: 0.9807 - auc: 0.9937 - val_loss: 0.1945 - val_tp: 8.0000 - val_fp: 1.0000 - val_tn: 7.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.9375 - val_precision: 0.8889 - val_recall: 1.0000 - val_auc: 0.9844
# Epoch 4/10
# 82/82 [==============================] - 21s 252ms/step - loss: 0.0664 - tp: 1955.2651 - fp: 30.1566 - tn: 669.3976 - fn: 31.6386 - accuracy: 0.9739 - precision: 0.9850 - recall: 0.9799 - auc: 0.9963 - val_loss: 0.7760 - val_tp: 8.0000 - val_fp: 5.0000 - val_tn: 3.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.6875 - val_precision: 0.6154 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 5/10
# 82/82 [==============================] - 21s 252ms/step - loss: 0.0839 - tp: 1964.3133 - fp: 39.3373 - tn: 656.0120 - fn: 26.7952 - accuracy: 0.9696 - precision: 0.9745 - recall: 0.9852 - auc: 0.9945 - val_loss: 0.1486 - val_tp: 8.0000 - val_fp: 1.0000 - val_tn: 7.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.9375 - val_precision: 0.8889 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 6/10
# 82/82 [==============================] - 21s 253ms/step - loss: 0.0356 - tp: 1976.0843 - fp: 17.5181 - tn: 673.7711 - fn: 19.0843 - accuracy: 0.9875 - precision: 0.9921 - recall: 0.9912 - auc: 0.9990 - val_loss: 0.3425 - val_tp: 8.0000 - val_fp: 4.0000 - val_tn: 4.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.7500 - val_precision: 0.6667 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 7/10
# 82/82 [==============================] - 20s 249ms/step - loss: 0.0242 - tp: 1985.9518 - fp: 10.4819 - tn: 682.1446 - fn: 7.8795 - accuracy: 0.9926 - precision: 0.9941 - recall: 0.9961 - auc: 0.9996 - val_loss: 0.1682 - val_tp: 8.0000 - val_fp: 3.0000 - val_tn: 5.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.8125 - val_precision: 0.7273 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 8/10
# 82/82 [==============================] - 20s 244ms/step - loss: 0.0206 - tp: 1981.5301 - fp: 8.3133 - tn: 687.9157 - fn: 8.6988 - accuracy: 0.9933 - precision: 0.9961 - recall: 0.9948 - auc: 0.9998 - val_loss: 0.3604 - val_tp: 8.0000 - val_fp: 3.0000 - val_tn: 5.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.8125 - val_precision: 0.7273 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 9/10
# 82/82 [==============================] - 20s 242ms/step - loss: 0.0128 - tp: 1985.2289 - fp: 2.2892 - tn: 695.5663 - fn: 3.3735 - accuracy: 0.9980 - precision: 0.9990 - recall: 0.9983 - auc: 1.0000 - val_loss: 0.0493 - val_tp: 8.0000 - val_fp: 0.0000e+00 - val_tn: 8.0000 - val_fn: 0.0000e+00 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 10/10
# 82/82 [==============================] - 20s 242ms/step - loss: 0.0120 - tp: 1992.7831 - fp: 0.6265 - tn: 689.5422 - fn: 3.5060 - accuracy: 0.9977 - precision: 0.9998 - recall: 0.9972 - auc: 0.9999 - val_loss: 0.5127 - val_tp: 8.0000 - val_fp: 3.0000 - val_tn: 5.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.8125 - val_precision: 0.7273 - val_recall: 1.0000 - val_auc: 1.0000
# CONFUSION MATRIX ------------------
# [[ 19 215]
#  [ 44 346]]
#
# TEST METRICS ----------------------
# Accuracy: 58.493589743589745%
# Precision: 61.67557932263814%
# Recall: 88.71794871794872%
# F1-score: 72.76550998948476
#
# TRAIN METRIC ----------------------
# Train acc: 99.88

# %% [markdown]
# ###### Checkpoint weights.

# %%
initial_weights = os.path.join(tempfile.mkdtemp(),'initial_weights')
model.save_weights(initial_weights)

# %% [markdown]
# ### V2 - Set class weights

# %%
# Scaling by total/2 helps keep the loss to a similar magnitude.
# The sum of the weights of all examples stays the same.
total = normal + pneumonia
weight_for_0 = (1 / normal)*(total)/2.0 
weight_for_1 = (1 / pneumonia)*(total)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))
# Out:
# Weight for class 0: 1.94
# Weight for class 1: 0.67

# %%
weighted_model = make_model(output_bias = initial_bias)
weighted_model.load_weights(initial_weights)

weighted_history = weighted_model.fit(
    dirs['train'],
    validation_data=dirs['val'],
    epochs=NUM_EPOCHS,
    # The class weights go here
    class_weight=class_weight) 

# Plot accuracy and loss
fig, ax = plt.subplots(1, 2, figsize=(10, 3))
ax = ax.ravel()

for i, met in enumerate(['accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])  
    
# Test
test_data = []
test_labels = []
input_path = 'chest_xray/chest_xray/'
for cond in ['/NORMAL/', '/PNEUMONIA/']:
    for img in (os.listdir(input_path + 'test' + cond)):
        img = plt.imread(input_path+'test'+cond+img)
        img = cv2.resize(img, (200, 200))
        img = np.dstack([img, img, img])
        img = img.astype('float32') / 255
        if cond=='/NORMAL/':
            label = 0
        elif cond=='/PNEUMONIA/':
            label = 1
        test_data.append(img)
        test_labels.append(label)

test_data = np.array(test_data)
test_labels = np.array(test_labels)

preds = model.predict(dirs['test'])

acc = accuracy_score(test_labels, np.round(preds))*100
cm = confusion_matrix(test_labels, np.round(preds))
tn, fp, fn, tp = cm.ravel()

print('CONFUSION MATRIX ------------------')
print(cm)

print('\nTEST METRICS ----------------------')
precision = tp/(tp+fp)*100
recall = tp/(tp+fn)*100
print('Accuracy: {}%'.format(acc))
print('Precision: {}%'.format(precision))
print('Recall: {}%'.format(recall))
print('F1-score: {}'.format(2*precision*recall/(precision+recall)))

print('\nTRAIN METRIC ----------------------')
print('Train acc: {}'.format(np.round((history.history['accuracy'][-1])*100, 2)))
# Out:
# Epoch 1/10
# 82/82 [==============================] - 22s 263ms/step - loss: 0.0037 - tp: 1999.1687 - fp: 3.0000 - tn: 698.1325 - fn: 2.1566 - accuracy: 0.9965 - precision: 0.9966 - recall: 0.9988 - auc: 0.9999 - val_loss: 0.1605 - val_tp: 8.0000 - val_fp: 1.0000 - val_tn: 7.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.9375 - val_precision: 0.8889 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 2/10
# 82/82 [==============================] - 20s 243ms/step - loss: 0.0017 - tp: 1991.1687 - fp: 0.0000e+00 - tn: 695.2892 - fn: 0.0000e+00 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0766 - val_tp: 8.0000 - val_fp: 0.0000e+00 - val_tn: 8.0000 - val_fn: 0.0000e+00 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 3/10
# 82/82 [==============================] - 20s 249ms/step - loss: 0.0012 - tp: 1994.0361 - fp: 0.0000e+00 - tn: 692.4217 - fn: 0.0000e+00 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1013 - val_tp: 8.0000 - val_fp: 1.0000 - val_tn: 7.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.9375 - val_precision: 0.8889 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 4/10
# 82/82 [==============================] - 20s 243ms/step - loss: 5.6142e-04 - tp: 1998.4337 - fp: 0.0000e+00 - tn: 688.0241 - fn: 0.0000e+00 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1027 - val_tp: 8.0000 - val_fp: 1.0000 - val_tn: 7.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.9375 - val_precision: 0.8889 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 5/10
# 82/82 [==============================] - 20s 248ms/step - loss: 4.1299e-04 - tp: 1996.6506 - fp: 0.0000e+00 - tn: 689.8072 - fn: 0.0000e+00 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0926 - val_tp: 8.0000 - val_fp: 1.0000 - val_tn: 7.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.9375 - val_precision: 0.8889 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 6/10
# 82/82 [==============================] - 20s 248ms/step - loss: 3.7747e-04 - tp: 1993.6145 - fp: 0.0000e+00 - tn: 692.8434 - fn: 0.0000e+00 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0663 - val_tp: 8.0000 - val_fp: 0.0000e+00 - val_tn: 8.0000 - val_fn: 0.0000e+00 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 7/10
# 82/82 [==============================] - 20s 248ms/step - loss: 3.1871e-04 - tp: 1990.5904 - fp: 0.0000e+00 - tn: 695.8675 - fn: 0.0000e+00 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0753 - val_tp: 8.0000 - val_fp: 0.0000e+00 - val_tn: 8.0000 - val_fn: 0.0000e+00 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 8/10
# 82/82 [==============================] - 20s 248ms/step - loss: 2.6072e-04 - tp: 1991.4337 - fp: 0.0000e+00 - tn: 695.0241 - fn: 0.0000e+00 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0928 - val_tp: 8.0000 - val_fp: 1.0000 - val_tn: 7.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.9375 - val_precision: 0.8889 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 9/10
# 82/82 [==============================] - 20s 247ms/step - loss: 1.9338e-04 - tp: 1992.7108 - fp: 0.0000e+00 - tn: 693.7470 - fn: 0.0000e+00 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0887 - val_tp: 8.0000 - val_fp: 1.0000 - val_tn: 7.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.9375 - val_precision: 0.8889 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 10/10
# 82/82 [==============================] - 20s 246ms/step - loss: 1.4857e-04 - tp: 1992.7349 - fp: 0.0000e+00 - tn: 693.7229 - fn: 0.0000e+00 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0661 - val_tp: 8.0000 - val_fp: 0.0000e+00 - val_tn: 8.0000 - val_fn: 0.0000e+00 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# CONFUSION MATRIX ------------------
# [[ 22 212]
#  [ 41 349]]
#
# TEST METRICS ----------------------
# Accuracy: 59.455128205128204%
# Precision: 62.21033868092691%
# Recall: 89.48717948717949%
# F1-score: 73.39642481598317
#
# TRAIN METRIC ----------------------
# Train acc: 99.88
